# %%
# Dependencies and Setup
import pandas as pd

# Load the csv files
jan = "2020/2020-01-west-midlands-street.csv"
feb = "2020/2020-02-west-midlands-street.csv"
mar = "2020/2020-03-west-midlands-street.csv"
apr = "2020/2020-04-west-midlands-street.csv"
may = "2020/2020-05-west-midlands-street.csv"
jun = "2020/2020-06-west-midlands-street.csv"
jul = "2020/2020-07-west-midlands-street.csv"
aug = "2020/2020-08-west-midlands-street.csv"
sep = "2020/2020-09-west-midlands-street.csv"
octo = "2020/2020-10-west-midlands-street.csv"
nov = "2020/2020-11-west-midlands-street.csv"
dec = "2020/2020-12-west-midlands-street.csv"

# store into Pandas DataFrames
df1 = pd.read_csv(jan)
df2 = pd.read_csv(feb)
df3 = pd.read_csv(mar)
df4 = pd.read_csv(apr)
df5 = pd.read_csv(may)
df6 = pd.read_csv(jun)
df7 = pd.read_csv(jul)
df8 = pd.read_csv(aug)
df9 = pd.read_csv(sep)
df10 = pd.read_csv(octo)
df11 = pd.read_csv(nov)
df12 = pd.read_csv(dec)

# append the dataframes into one
merge_2020_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index=True)
merge_2020_df
# Out:
#                                                  Crime ID    Month  \
# 0                                                     NaN  2020-01
# 1       1b1d402a12d6d89a66b7b5b453300bf201cf43f79ff2d7...  2020-01
# 2       7e65a6f780e3e6dbb93d4e161ca9a5a6ef2498dd8168e5...  2020-01
# 3       63ac41d45bbf2402bd1a8c1202ffd7554cae4de84d59b1...  2020-01
# 4       376e737edfa06c918d07bcac79c4b3395dd33e169663a9...  2020-01
# ...                                                   ...      ...
# 322792  ca4019deaf155b01f7268111c0e1ed0bd2b5c2de432d10...  2020-12
# 322793  462c3cbc43005081a24ed786fb8f80977a96eab2c345fd...  2020-12
# 322794  47ea543c96c063ba65cbcd7ebfb2cc60290b9f28296e8c...  2020-12
# 322795  fe8e5364f4762efad039c67152403e5fffbc4f0e5733f8...  2020-12
# 322796  53c759572985a520aee164c92a602e66af65c4c833328b...  2020-12
#
#                  Reported by          Falls within  Longitude   Latitude  \
# 0       West Midlands Police  West Midlands Police  -1.841944  52.597265
# ...

# %%
len(merge_2020_df)
# Out:
# 322797

# %%
# merge_2020_df.to_csv("2020.csv")
