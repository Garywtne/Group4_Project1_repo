# %%
# Dependencie
import pandas as pd

# %%
# Load in file
r2019 = "reduced_2019.csv"

# %%
r2019
# Out:
# 'reduced_2019.csv'

# %%
# Read and display the CSV with Pandas
r2019_df = pd.read_csv(r2019)
r2019_df.head()
# Out:
#                                             Crime ID  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
#
#                   Crime type                          Last outcome category  \
# 0                   Burglary  Investigation complete; no suspect identified
# 1                Other theft  Investigation complete; no suspect identified
# 2               Public order  Investigation complete; no suspect identified
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson  Investigation complete; no suspect identified
#
#      Month  Longitude   Latitude                    Location  LSOA code  \
# 0  2019-01  -1.850519  52.589275       On or near Crown Lane  E01009417
# ...

# %%
r2019_df.count()
# Out:
# Crime ID                                                                 259543
# Crime type                                                               296032
# Last outcome category                                                    259543
# Month                                                                    296032
# Longitude                                                                296032
# Latitude                                                                 296032
# Location                                                                 296032
# LSOA code                                                                296032
# LSOA name                                                                296032
# District code (2019)                                                     296032
# District name (2019)                                                     296032
# Description                                                              296032
# ...

# %%
# making data frame from csv file
data = pd.read_csv("reduced_2019.csv", index_col ="LSOA name" )
 
# dropping passed values
data.drop(['Basingstoke and Deane','Bassetlaw','Blaby','Bristol,City of','Bromsgrove','Calderdale','Cheshire West and Chester','Chichester','Corby','Cornwall','Cotswold','County Durham','Daventry','Derbyshire Dales','Doncaster','East Hampshire','East Northamptonshire','Exeter','Folkestone and Hythe','Fylde','Hambleton','Harborough','Hartlepool','Hastings','High Peak','Isle of Wight','Isles of Scilly','Kettering',"King's Lynn and West Norfolk",'Kirklees','Leeds','Lewes','Lichfield','Malvern Hills','North Warwickshire','Nuneaton and Bedworth','Oldham','Oxford','Richmondshire','Rossendale','Rother','Rotherham','Rugby','Sheffield','Shropshire','South Hams','South Staffordshire','Stockport','Stratford-on-Avon','Swindon','Tameside','Tamworth','Tewkesbury','Tunbridge Wells','Warwick','West Oxfordshire','Westminster','Wiltshire','Worthing','Wychavon'
 ], inplace = True)

data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2196/181713680.py in <module>
#       3
#       4 # dropping passed values
# ...
