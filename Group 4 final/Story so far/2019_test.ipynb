# %%
# Dependencies and Setup
import pandas as pd

# Load the csv files
file = "2019.csv"

# store into Pandas DataFrames
df1 = pd.read_csv(file)

df1
# Out:
#         Unnamed: 0                                           Crime ID  \
# 0                0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1                1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2                2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3                3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4                4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
# ...            ...                                                ...
# 296027      296027  1ab1e1464e7f6afe100882e02385d1ce4685c83d7df7fe...
# 296028      296028  f888be8f38650b8506010ba66e1e71866998215ff93b18...
# 296029      296029  1aca50c3375198807bff67047413fe1e8ab5e61e37ce82...
# 296030      296030  1787a4b890ce875fe1a4fa4badcf37c0da665c55251ad2...
# 296031      296031  b7f263b2302d5b190ba29338fea7af231b7a1612195a91...
#
#           Month  Longitude   Latitude                       Location  \
# ...

# %%
del df1['Unnamed: 0']

# %%
df1.head()
# Out:
#                                             Crime ID    Month  Longitude  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...  2019-01  -1.850519
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...  2019-01  -1.850056
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...  2019-01  -1.850772
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...  2019-02  -1.850772
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...  2019-02  -1.850772
#
#     Latitude                    Location  LSOA code        LSOA name  \
# 0  52.589275       On or near Crown Lane  E01009417  Birmingham 001A
# 1  52.591108     On or near Walsall Road  E01009417  Birmingham 001A
# 2  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 3  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 4  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
#
#                   Crime type                          Last outcome category  \
# ...

# %%
df1.describe()
# Out:
#            Longitude       Latitude  \
# count  296032.000000  296032.000000
# mean       -1.901119      52.494124
# std         0.179661       0.072056
# min        -6.347315      49.892149
# 25%        -2.020886      52.446656
# 50%        -1.921611      52.485786
# 75%        -1.830662      52.539102
# max         0.964142      54.832031
#
#        Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# count                                      296032.000000
# mean                                            2.892985
# std                                             2.235089
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             4.000000
# max                                            10.000000
#
#        Income Decile (where 1 is most deprived 10% of LSOAs)  \
# ...

# %%
Crime = df1.set_index(["Crime type"])["Local Authority District name (2019)_x"]
Crime
# Out:
# Crime type
# Burglary                                   Birmingham
# Other theft                                Birmingham
# Public order                               Birmingham
# Criminal damage and arson                  Birmingham
# Criminal damage and arson                  Birmingham
#                                         ...
# Violence and sexual offences                  Swindon
# Violence and sexual offences    East Northamptonshire
# Criminal damage and arson                       Fylde
# Violence and sexual offences                    Fylde
# Violence and sexual offences     Folkestone and Hythe
# Name: Local Authority District name (2019)_x, Length: 296032, dtype: object

# %%
Crime_count = df1["Crime type"].value_counts()
Crime_count
# Out:
# Violence and sexual offences    95928
# Anti-social behaviour           36489
# Vehicle crime                   32418
# Burglary                        24984
# Criminal damage and arson       24910
# Other theft                     20743
# Public order                    16948
# Shoplifting                     16339
# Robbery                          8790
# Drugs                            5641
# Other crime                      4301
# Theft from the person            3060
# Possession of weapons            3027
# Bicycle theft                    2454
# Name: Crime type, dtype: int64

# %%
w_mids = (df1["Local Authority District name (2019)_x"] == "Birmingham") | (df1["Local Authority District name (2019)_x"] == "Coventry") | (df1["Local Authority District name (2019)_x"] == "Solihull")| (df1["Local Authority District name (2019)_x"] == "Sandwell")| (df1["Local Authority District name (2019)_x"] == "Dudley") | (df1["Local Authority District name (2019)_x"] == "Walsall")| (df1["Local Authority District name (2019)_x"] == "Wolverhampton")
df1.loc[w_mids, :]
# Out:
#                                                  Crime ID    Month  Longitude  \
# 0       b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...  2019-01  -1.850519
# 1       b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...  2019-01  -1.850056
# 2       2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...  2019-01  -1.850772
# 3       0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...  2019-02  -1.850772
# 4       cadab8dbc07947f5db64c9c0206077758cbbad346611cc...  2019-02  -1.850772
# ...                                                   ...      ...        ...
# 295867  2df4c5896b1d9840fea818148ab7331fcb4e728093aba8...  2019-12  -2.161798
# 295868  2487d31a74df5df8dd9cc544c0a57fb9c4c5ce3ea4aeef...  2019-12  -2.161798
# 295869  ddf5c65ed97e0e3cf2d684829d74ae8c9d1307e4ac4d0d...  2019-12  -2.161798
# 295870  c363adc27ade9b9d5aa99796b2b461db88d4d76dfd1bf5...  2019-12  -2.158590
# 295871  10611c6ca00a249d5b517f4b39047a0067aac5306256a1...  2019-12  -2.153027
#
# ...

# %%
w_mids.dtypes
# Out:
# dtype('bool')

# %%
df1.dtypes
# Out:
# Crime ID                                                                               object
# Month                                                                                  object
# Longitude                                                                             float64
# Latitude                                                                              float64
# Location                                                                               object
# LSOA code                                                                              object
# LSOA name                                                                              object
# Crime type                                                                             object
# Last outcome category                                                                  object
# Local Authority District code (2019)                                                   object
# ...

# %%
df1.count()
# Out:
# Crime ID                                                                              259543
# Month                                                                                 296032
# Longitude                                                                             296032
# Latitude                                                                              296032
# Location                                                                              296032
# LSOA code                                                                             296032
# LSOA name                                                                             296032
# Crime type                                                                            296032
# Last outcome category                                                                 259543
# Local Authority District code (2019)                                                  296032
# ...

# %%
df2 = df1.rename(columns={' Total population1':'Population'})
df2.head()
# Out:
#                                             Crime ID    Month  Longitude  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...  2019-01  -1.850519
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...  2019-01  -1.850056
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...  2019-01  -1.850772
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...  2019-02  -1.850772
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...  2019-02  -1.850772
#
#     Latitude                    Location  LSOA code        LSOA name  \
# 0  52.589275       On or near Crown Lane  E01009417  Birmingham 001A
# 1  52.591108     On or near Walsall Road  E01009417  Birmingham 001A
# 2  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 3  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 4  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
#
#                   Crime type                          Last outcome category  \
# ...

# %%
df2 = df2.rename(columns={'Local Authority District code (2019)':'District code (2019)'})
df2 = df2.rename(columns={'Local Authority District name (2019)_x':'District name (2019)'})
df2 = df2.rename(columns={'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)':'Index of Multiple Deprivation (IMD)'})
df2 = df2.rename(columns={'RUC11':'Description'})
df2.head()
# Out:
#                                             Crime ID    Month  Longitude  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...  2019-01  -1.850519
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...  2019-01  -1.850056
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...  2019-01  -1.850772
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...  2019-02  -1.850772
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...  2019-02  -1.850772
#
#     Latitude                    Location  LSOA code        LSOA name  \
# 0  52.589275       On or near Crown Lane  E01009417  Birmingham 001A
# 1  52.591108     On or near Walsall Road  E01009417  Birmingham 001A
# 2  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 3  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 4  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
#
#                   Crime type                          Last outcome category  \
# ...

# %%
df2.head()
# Out:
#                                             Crime ID    Month  Longitude  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...  2019-01  -1.850519
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...  2019-01  -1.850056
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...  2019-01  -1.850772
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...  2019-02  -1.850772
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...  2019-02  -1.850772
#
#     Latitude                    Location  LSOA code        LSOA name  \
# 0  52.589275       On or near Crown Lane  E01009417  Birmingham 001A
# 1  52.591108     On or near Walsall Road  E01009417  Birmingham 001A
# 2  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 3  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 4  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
#
#                   Crime type                          Last outcome category  \
# ...

# %%
df2 = df2.rename(columns={'Income deprivation- Average score':'Income deprivation'})

# %%
df2.head()
# Out:
#                                             Crime ID    Month  Longitude  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...  2019-01  -1.850519
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...  2019-01  -1.850056
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...  2019-01  -1.850772
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...  2019-02  -1.850772
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...  2019-02  -1.850772
#
#     Latitude                    Location  LSOA code        LSOA name  \
# 0  52.589275       On or near Crown Lane  E01009417  Birmingham 001A
# 1  52.591108     On or near Walsall Road  E01009417  Birmingham 001A
# 2  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 3  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 4  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
#
#                   Crime type                          Last outcome category  \
# ...

# %%
columns = [
    "Crime ID",
    "Crime type",
    "Last outcome category",
    "Month",
    "Longitude",
    "Latitude",
    "LSOA code",
    "LSOA name",
    "District code (2019)",
    "District name (2019)",
    "Description",
    "Population",
]

# %%
# birmingham = df2.loc[df2['District name (2019)'] == 'Birmingham'| (df2["District name (2019)"] == "Coventry") | (df2["District name (2019)"] == "Solihull")| (df2["District name (2019)"] == "Sandwell")| (df2["District name (2019)"] == "Dudley") | (df2["District name (2019)"] == "Walsall")| (df1["District name (2019)"] == "Wolverhampton"), columns]

birmingham = df2.loc[df2['District name (2019)'] == 'Birmingham', columns]
birmingham.head()
# Out:
#                                             Crime ID  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
#
#                   Crime type                          Last outcome category  \
# 0                   Burglary  Investigation complete; no suspect identified
# 1                Other theft  Investigation complete; no suspect identified
# 2               Public order  Investigation complete; no suspect identified
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson  Investigation complete; no suspect identified
#
#      Month  Longitude   Latitude  LSOA code        LSOA name  \
# 0  2019-01  -1.850519  52.589275  E01009417  Birmingham 001A
# 1  2019-01  -1.850056  52.591108  E01009417  Birmingham 001A
# ...

# %%
df2.head()
# Out:
#                                             Crime ID    Month  Longitude  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...  2019-01  -1.850519
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...  2019-01  -1.850056
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...  2019-01  -1.850772
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...  2019-02  -1.850772
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...  2019-02  -1.850772
#
#     Latitude                    Location  LSOA code        LSOA name  \
# 0  52.589275       On or near Crown Lane  E01009417  Birmingham 001A
# 1  52.591108     On or near Walsall Road  E01009417  Birmingham 001A
# 2  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 3  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
# 4  52.588691  On or near Seymour Gardens  E01009417  Birmingham 001A
#
#                   Crime type                          Last outcome category  \
# ...

# %%
df2.columns
# Out:
# Index(['Crime ID', 'Month', 'Longitude', 'Latitude', 'Location', 'LSOA code',
#        'LSOA name', 'Crime type', 'Last outcome category',
#        'District code (2019)', 'District name (2019)',
#        'Index of Multiple Deprivation (IMD)',
#        'Income Decile (where 1 is most deprived 10% of LSOAs)', 'Description',
#        'Population',
#        'Rural including hub towns (rural & rural related) % population1 ',
#        'Local Authority District name (2019)_y',
#        'Income deprivation- Average score ',
#        'Income deprivation - Rank of average score ',
#        'Income - Proportion of LSOAs in most deprived 10% nationally ',
#        'Income - Rank of proportion of LSOAs in most deprived 10% nationally '],
#       dtype='object')

# %%
df3 = df2[['Crime ID','Crime type', 'Last outcome category','Month', 'Longitude', 'Latitude', 'Location', 'LSOA code',
       'LSOA name',  
       'District code (2019)', 'District name (2019)','Description','Population',
       'Index of Multiple Deprivation (IMD)',
       'Income deprivation- Average score ',
       'Income deprivation - Rank of average score ',
       'Income - Rank of proportion of LSOAs in most deprived 10% nationally ']]
df3.head()
# Out:
#                                             Crime ID  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
#
#                   Crime type                          Last outcome category  \
# 0                   Burglary  Investigation complete; no suspect identified
# 1                Other theft  Investigation complete; no suspect identified
# 2               Public order  Investigation complete; no suspect identified
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson  Investigation complete; no suspect identified
#
#      Month  Longitude   Latitude                    Location  LSOA code  \
# 0  2019-01  -1.850519  52.589275       On or near Crown Lane  E01009417
# ...

# %%
df3.to_csv('../reduced_2019.csv', index=False)
